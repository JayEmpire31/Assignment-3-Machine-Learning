# %%
import pandas as pd
import numpy as np

# %%
oils = pd.read_csv('Train.csv')

# %%
oils
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
oils.head(15)
# Out:
#     ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0    1               D           Flight                    4                2
# 1    2               F           Flight                    4                5
# 2    3               A           Flight                    2                2
# 3    4               B           Flight                    3                3
# 4    5               C           Flight                    2                2
# 5    6               F           Flight                    3                1
# 6    7               D           Flight                    3                4
# 7    8               F           Flight                    4                1
# 8    9               A           Flight                    3                4
# 9   10               B           Flight                    3                2
# 10  11               C           Flight                    3                4
# ...

# %%
oils.dropna()
oils.drop(columns=['ID','Customer_care_calls','Prior_purchases','Gender','Reached.on.Time_Y.N'])
# Out:
#       Warehouse_block Mode_of_Shipment  Customer_rating  Cost_of_the_Product  \
# 0                   D           Flight                2                  177
# 1                   F           Flight                5                  216
# 2                   A           Flight                2                  183
# 3                   B           Flight                3                  176
# 4                   C           Flight                2                  184
# ...               ...              ...              ...                  ...
# 10994               A             Ship                1                  252
# 10995               B             Ship                1                  232
# 10996               C             Ship                4                  242
# 10997               F             Ship                2                  223
# 10998               D             Ship                5                  155
#
# ...

# %%
oilsA=pd.DataFrame({'Mode_of_Shipment':['Flight','Ship','Road']})
oilsB=pd.DataFrame({'Product_importance':['low','medium','high']})
oilsA
# Out:
#   Mode_of_Shipment
# 0           Flight
# 1             Ship
# 2             Road

# %%
oilsB
# Out:
#   Product_importance
# 0                low
# 1             medium
# 2               high

# %% [markdown]
# ## Section 4

# %%
oils.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# dtype: object

# %%
oils.columns
feature_oils = oils[[ 'Customer_care_calls',
       'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
        'Discount_offered',
       'Reached.on.Time_Y.N']]
X = np.asarray(feature_oils)
Y = np.asarray(oils['Weight_in_gms'])
X[0:5]
# Out:
# array([[  4,   2, 177,   3,  44,   1],
#        [  4,   5, 216,   2,  59,   1],
#        [  2,   2, 183,   4,  48,   1],
#        [  3,   3, 176,   4,  10,   1],
#        [  2,   2, 184,   3,  46,   1]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=4)

# %% [markdown]
# Conclusion
# Due to issues with the Jupyter Notebook, i was unable to fully complete the linear regression and classification as I hoped. Based on the initial results, it looked like TV was the best effective method to advertise a product.

# %%
from sklearn import svm

# %%
Classifier = svm.SVC(kernel='linear',gamma='auto', C=2)
Classifier.fit(X_train,Y_train)
y_predict = Classifier.predict(X_test)

# %%
From sklearn.metrics import classification_report
